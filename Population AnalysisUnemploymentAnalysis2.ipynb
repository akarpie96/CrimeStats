# %%
# %matplotlib notebook
import pandas as pd
from scipy.stats import linregress
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from matplotlib.pyplot import figure

# %%
Pop_df=pd.read_csv('Clean_Data_Output/Population_Data.csv')
new_pop=pd.read_csv('Resources/Census_Pop_2019.csv')

# %%
Pop_df
# Out:
#     Unnamed: 0                 State  Population (2019)  Total Murders (2019)
# 0            0               Alabama           731545.0                   4.0
# 1            1                Alaska          7278717.0                  69.0
# 2            2               Arizona          3017804.0                 337.0
# 3            3              Arkansas         39512223.0                 231.0
# 4            4            California          5758736.0                1679.0
# 5            5              Colorado          3565287.0                 209.0
# 6            6           Connecticut           973764.0                 104.0
# 7            7              Delaware           705749.0                  48.0
# 8            8  District of Columbia         21477737.0                 166.0
# 9            9               Florida         10617423.0                   1.0
# 10          10               Georgia          1415872.0                 445.0
# ...

# %%
Pop_df=Pop_df[["State", "Population (2019)", "Total Murders (2019)"]]

# %%
Bottom_Five_df=Pop_df.sort_values(by="Population (2019)", ascending=True).head()

# %%
Bottom_Five_df
# Out:
#                    State  Population (2019)  Total Murders (2019)
# 50               Wyoming           578759.0                  13.0
# 45               Vermont           623989.0                  11.0
# 8   District of Columbia           705749.0                 166.0
# 1                 Alaska           731545.0                  69.0
# 34          North Dakota           762062.0                  26.0

# %%
Top_Five_df=Pop_df.sort_values(by="Population (2019)", ascending=False).head()

# %%
Top_Five_df
# Out:
#            State  Population (2019)  Total Murders (2019)
# 4     California         39512223.0                1679.0
# 43         Texas         28995881.0                1379.0
# 9        Florida         21477737.0                   1.0
# 32      New York         19453561.0                 550.0
# 38  Pennsylvania         12801989.0                 556.0

# %%
state=Pop_df["State"]

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(Pop_df["Population (2019)"], Pop_df["Total Murders (2019)"])
regress_values = Pop_df["Population (2019)"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(Pop_df["Population (2019)"], Pop_df["Total Murders (2019)"])
plt.title('State Homicide Count relative to Population',fontsize =12)
plt.xlabel('State Population (millions)',fontsize =10)
plt.ylabel('Homicides (2019)',fontsize =10)
plt.plot(Pop_df["Population (2019)"],regress_values,"r-")
plt.savefig("Image Output/Population_Regression.png")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(6, 10, 'y = 0.0x + 29.21')

# %%
Pop_df["2019 Population"]=new_pop["2019 Population"]

# %%
Pop=Pop_df["2019 Population"].str.replace(",", "").astype(float)

# %%
Pop_df["2019 Population"]=Pop

# %%
Pop_df
# Out:
#     Unnamed: 0                 State  Population (2019)  Total Murders (2019)  \
# 0            0               Alabama           731545.0                   4.0
# 1            1                Alaska          7278717.0                  69.0
# 2            2               Arizona          3017804.0                 337.0
# 3            3              Arkansas         39512223.0                 231.0
# 4            4            California          5758736.0                1679.0
# 5            5              Colorado          3565287.0                 209.0
# 6            6           Connecticut           973764.0                 104.0
# 7            7              Delaware           705749.0                  48.0
# 8            8  District of Columbia         21477737.0                 166.0
# 9            9               Florida         10617423.0                   1.0
# 10          10               Georgia          1415872.0                 445.0
# ...

# %%
Pop_df["Murders Per Capita/Homicide Rate"]=(round(Pop_df["Total Murders (2019)"]/Pop_df["2019 Population"],5))

# %%
Pop_df=Pop_df[["State", "Total Murders (2019)", "2019 Population", "Murders Per Capita/Homicide Rate"]]

# %%
Pop_df
# Out:
#                    State  Total Murders (2019)  2019 Population  \
# 0                Alabama                   4.0        4903185.0
# 1                 Alaska                  69.0         731545.0
# 2                Arizona                 337.0        7278717.0
# 3               Arkansas                 231.0        3017804.0
# 4             California                1679.0       39512223.0
# 5               Colorado                 209.0        5758736.0
# 6            Connecticut                 104.0        3565287.0
# 7               Delaware                  48.0         973764.0
# 8   District of Columbia                 166.0         705749.0
# 9                Florida                   1.0       21477737.0
# 10               Georgia                 445.0       10617423.0
# 11                Hawaii                  32.0        1415872.0
# 12                 Idaho                  35.0        1787065.0
# 13              Illinois                 771.0       12671821.0
# ...

# %%
unemp_df=pd.read_csv('Resources/state_unemployment.csv')

# %%
Pop_df["Unemployment Rate"]=unemp_df["unemployment_rate"]
# Out:
# <ipython-input-12-d1cd3c0c58c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pop_df["Unemployment Rate"]=unemp_df["unemployment_rate"]

# %%
Pop_df
# Out:
#                    State  Total Murders (2019)  2019 Population  \
# 0                Alabama                   4.0        4903185.0
# 1                 Alaska                  69.0         731545.0
# 2                Arizona                 337.0        7278717.0
# 3               Arkansas                 231.0        3017804.0
# 4             California                1679.0       39512223.0
# 5               Colorado                 209.0        5758736.0
# 6            Connecticut                 104.0        3565287.0
# 7               Delaware                  48.0         973764.0
# 8   District of Columbia                 166.0         705749.0
# 9                Florida                   1.0       21477737.0
# 10               Georgia                 445.0       10617423.0
# 11                Hawaii                  32.0        1415872.0
# 12                 Idaho                  35.0        1787065.0
# 13              Illinois                 771.0       12671821.0
# ...

# %%
Pop_df=Pop_df.sort_values(by="Unemployment Rate")

# %%
fig=plt.scatter(Pop_df["Unemployment Rate"], Pop_df["Murders Per Capita/Homicide Rate"])
(slope, intercept, rvalue, pvalue, stderr) = linregress(Pop_df["Unemployment Rate"], Pop_df["Murders Per Capita/Homicide Rate"])
regress_values = Pop_df["Unemployment Rate"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title('State Homicide Rate relative to Unemployment Rate',fontsize =12)
plt.xlabel('Unemployment Rate',fontsize =10)
plt.ylabel('Homicide Rate',fontsize =10)
plt.plot(Pop_df["Unemployment Rate"],regress_values,"r-")
plt.savefig("Image Output/UnemploymentRatevsHomicideRate.png",bbox_inches="tight")

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Pop_df.to_csv("Clean_Data_Output/Clean_Data_Final.csv", index=True)

# %%
correlation = st.pearsonr(Pop_df["Unemployment Rate"],Pop_df["Murders Per Capita/Homicide Rate"])

# %%
correlation
# Out:
# (0.5024693751888138, 0.00017176602976264754)

# %%
print(f"The correlation between both factors is {round(correlation[0],2)} or moderately correlated")
# Out:
# The correlation between both factors is 0.5 or moderately correlated
