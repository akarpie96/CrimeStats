# %%
# -*- coding: utf-8 -*-
#"""
#Yelp Fusion API code sample.
#This program demonstrates the capability of the Yelp Fusion API
#by using the Search API to query for businesses by a search term and location,
#and the Business API to query additional information about the top result
#from the search query.
#Please refer to http://www.yelp.com/developers/v3/documentation for the API
#documentation.
#This program requires the Python requests library, which you can install via:
#`pip install -r requirements.txt`.
#Sample usage of the program:
#`python sample.py --term="bars" --location="San Francisco, CA"`
#"""

import json
import pprint
import requests
import sys
import urllib


# Yelp Fusion no longer uses OAuth as of December 7, 2017.
# You no longer need to provide Client ID to fetch Data
# It now uses private keys to authenticate requests (API Key)
# You can find it on
# https://www.yelp.com/developers/v3/manage_app

API_KEY= 'm_3Mrd7vBRmN31dfol91wxJzOxftKaI5a07izUbTrSKrGZdZWzwPnsAL3x1L0MHdxq5VkZeavnLXb-Ya8z7OA1qsM6Xdp0bXrwdV5BcHiHfwp3JxLJF8wrbvWOMQYHYx' 


# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.


# Defaults for our simple example.
DEFAULT_TERM = 1
DEFAULT_LOCATION = 'Dallas, TX'
SEARCH_LIMIT = 3



url_params = {
    #'location': 'Dallas, TX',
    'location': 77449,

}

url = 'https://api.yelp.com/v3/businesses/search?'
headers = {
    'Authorization': 'Bearer %s' % API_KEY,
}

print(u'Querying {0} ...'.format(url))

response = requests.get(url, headers=headers, params=url_params)

response.json()
# Out:
# Querying https://api.yelp.com/v3/businesses/search? ...
# {'businesses': [{'id': 'qK9eZkes1UFQAccQLhZp7w',
#    'alias': 'thats-my-dog-katy',
#    'name': "That's My Dog",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IGhj2R70CH1AoDwz5roZOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thats-my-dog-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 330,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 29.8167339466432,
#     'longitude': -95.7641260912204},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '22635 Morton Ranch Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['22635 Morton Ranch Rd', 'Katy, TX 77449']},
#    'phone': '+18302747538',
#    'display_phone': '(830) 274-7538',
#    'distance': 3197.01265121458},
#   {'id': 'gL9IAdUa87a21Yg4QtlqpQ',
#    'alias': 'joy-love-burgers-katy',
#    'name': 'Joy Love Burgers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1izVU1VE8snNO2RSlZ-P-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joy-love-burgers-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 449,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.799315, 'longitude': -95.752578},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1801 N Mason Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1801 N Mason Rd', 'Katy, TX 77449']},
#    'phone': '+18324378831',
#    'display_phone': '(832) 437-8831',
#    'distance': 3988.6786204127025},
#   {'id': 'cid6sUGOECc-Oo1NmJ9imQ',
#    'alias': 'ritters-frozen-custard-katy',
#    'name': "Ritter's Frozen Custard",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9il3mhZJyEMye5olEiHr1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ritters-frozen-custard-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 219,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.82158, 'longitude': -95.72073},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3427 N Fry Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3427 N Fry Rd', 'Katy, TX 77449']},
#    'phone': '+12816461211',
#    'display_phone': '(281) 646-1211',
#    'distance': 1917.5310654258208},
#   {'id': 'HdpfltmzEoRpZ6-f1mL7xQ',
#    'alias': 'tea-top-katy-6',
#    'name': 'Tea Top',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KsGPfcWvF1zjNhfcrcsikQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-top-katy-6?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 151,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7925678, 'longitude': -95.7740964},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '23119 Colonial Pkwy',
#     'address2': 'Ste C7',
#     'address3': None,
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['23119 Colonial Pkwy', 'Ste C7', 'Katy, TX 77449']},
#    'phone': '+18324378786',
#    'display_phone': '(832) 437-8786',
#    'distance': 5729.456457136829},
#   {'id': 'PYtDg_EgVG_7vEizQcm7fQ',
#    'alias': 'chungchun-sul-bing-su-katy',
#    'name': 'ChungChun - Sul Bing Su',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/seuvLU1wFP0KXRvYHwyN6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chungchun-sul-bing-su-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 275,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.792265, 'longitude': -95.775012},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '23119 Colonial Pkwy',
#     'address2': 'Ste B-16',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['23119 Colonial Pkwy', 'Ste B-16', 'Katy, TX 77449']},
#    'phone': '+18329307802',
#    'display_phone': '(832) 930-7802',
#    'distance': 5811.903671687936},
#   {'id': '2vtdcXzW-1PbsWH7Nkrubw',
#    'alias': 'pho-saigon-katy',
#    'name': 'Pho Saigon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EUkYN4lReBoWsQw3wvWw6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-saigon-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 540,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7700122, 'longitude': -95.7522791},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '890 S Mason Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77450',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['890 S Mason Rd', 'Katy, TX 77450']},
#    'phone': '+12813929022',
#    'display_phone': '(281) 392-9022',
#    'distance': 7093.166493891394},
#   {'id': 'h8MhdK4TEthF3xhNOLQmcA',
#    'alias': 'pho-chopstix-katy',
#    'name': 'Pho ChopstiX',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/K38pYG3lXAqx-0l0OZNpeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-chopstix-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 124,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.8000676319874,
#     'longitude': -95.7525232806802},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1829 N Mason Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1829 N Mason Rd', 'Katy, TX 77449']},
#    'phone': '+18323036355',
#    'display_phone': '(832) 303-6355',
#    'distance': 3909.8175107847837},
#   {'id': 'aZ2wWTpmA0JvyAWcvqZuPA',
#    'alias': 'angels-churros-n-chocolate-cypress',
#    'name': 'Angels Churros N Chocolate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ObC3FrndEUYYEDIik2NZGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angels-churros-n-chocolate-cypress?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 362,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gelato', 'title': 'Gelato'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.882782, 'longitude': -95.682906},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7160 Barker Cypress Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Cypress',
#     'zip_code': '77433',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['7160 Barker Cypress Rd', 'Cypress, TX 77433']},
#    'phone': '+18327700802',
#    'display_phone': '(832) 770-0802',
#    'distance': 7623.573894059302},
#   {'id': 'p_-yYBDIorgy7EdV249dHg',
#    'alias': 'yuriria-taquerias-express-katy-2',
#    'name': 'Yuriria Taquerias Express',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tGAZbR-9IhqIpBQJJVLBNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuriria-taquerias-express-katy-2?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 165,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.85031, 'longitude': -95.718156},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5502 Fry Rd',
#     'address2': 'Ste G',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5502 Fry Rd', 'Ste G', 'Katy, TX 77449']},
#    'phone': '+12815505555',
#    'display_phone': '(281) 550-5555',
#    'distance': 2658.4177091012994},
#   {'id': 'bLtBg14TUtS5jpdYID8Qsw',
#    'alias': 'larosh-grill-katy',
#    'name': 'Larosh Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gbJ9BHBDWvgJHUf8p5TAcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/larosh-grill-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 192,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'pakistani', 'title': 'Pakistani'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.8645978445566,
#     'longitude': -95.6971048298471},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '18855 W Little York Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['18855 W Little York Rd', 'Katy, TX 77449']},
#    'phone': '+12818614612',
#    'display_phone': '(281) 861-4612',
#    'distance': 5144.554660102608},
#   {'id': 'HoA4NjHNeXzGBcFgXXV8DQ',
#    'alias': 'somisomi-katy-3',
#    'name': 'SomiSomi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TwXj-zVd8At_zNP-aYWKzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somisomi-katy-3?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 152,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.789052, 'longitude': -95.773144},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '23330 Grand Cir Blvd',
#     'address2': 'Ste 150',
#     'address3': None,
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['23330 Grand Cir Blvd', 'Ste 150', 'Katy, TX 77449']},
#    'phone': '+13463876802',
#    'display_phone': '(346) 387-6802',
#    'distance': 5980.672386082269},
#   {'id': 'DC2T6oxWqa7VVIgRRY93pw',
#    'alias': 'fusion-36-degree-katy',
#    'name': 'Fusion 36 Degree',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nZg8Opm-sb7vnjOpxXFWCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fusion-36-degree-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 146,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.83073, 'longitude': -95.71941},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3950 N Fry Rd',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3950 N Fry Rd', 'Ste 100', 'Katy, TX 77449']},
#    'phone': '+12815791828',
#    'display_phone': '(281) 579-1828',
#    'distance': 1648.2623742759247},
#   {'id': 'TiYX_nwblP1wgmocdBwCwg',
#    'alias': 'the-bagel-café-katy-2',
#    'name': 'The Bagel Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N2Lv51n9nPexMRFVfZke7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagel-caf%C3%A9-katy-2?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 267,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7730821403187,
#     'longitude': -95.7507372647524},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '631 S Mason Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77450',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['631 S Mason Rd', 'Katy, TX 77450']},
#    'phone': '+12816467474',
#    'display_phone': '(281) 646-7474',
#    'distance': 6727.933300762673},
#   {'id': '4RrOMr3ihyv9OVihLi5Q2g',
#    'alias': 'star-wok-asian-bistro-cypress',
#    'name': 'Star Wok Asian Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MwK7Vu5Nwom0nY7ivEidLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/star-wok-asian-bistro-cypress?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 169,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.8781778418298,
#     'longitude': -95.7211132708233},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '20323 Fm 529 Rd',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'Cypress',
#     'zip_code': '77433',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['20323 Fm 529 Rd', 'Ste 100', 'Cypress, TX 77433']},
#    'phone': '+18324276259',
#    'display_phone': '(832) 427-6259',
#    'distance': 5309.493555481222},
#   {'id': 'v1VF3vTpqH7bx3DML6B-lw',
#    'alias': 'kravin-desserts-and-tapioca-katy-2',
#    'name': "Kravin' Desserts & Tapioca",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hf0e8KeYBL_ZSfpR1TLqXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kravin-desserts-and-tapioca-katy-2?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 142,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7858749, 'longitude': -95.7435405},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '21788 Katy Fwy',
#     'address2': 'Ste 200',
#     'address3': None,
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['21788 Katy Fwy', 'Ste 200', 'Katy, TX 77449']},
#    'phone': '+18328881599',
#    'display_phone': '(832) 888-1599',
#    'distance': 5170.429218441349},
#   {'id': 'KwpiBaDRbmzf2LY2sCO4Lg',
#    'alias': 'phanh-tastic-pho-katy-2',
#    'name': 'Phanh-tastic Pho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S-Z4AeGjKu4D3LPPMX0CPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phanh-tastic-pho-katy-2?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 59,
#    'categories': [{'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 29.78924, 'longitude': -95.77239},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '23227 Mercantile Pkwy',
#     'address2': 'Ste a-1',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['23227 Mercantile Pkwy', 'Ste a-1', 'Katy, TX 77449']},
#    'phone': '+18324370687',
#    'display_phone': '(832) 437-0687',
#    'distance': 5923.224361353536},
#   {'id': 'Ul84JztZ69FVwmDp1jaSBw',
#    'alias': 'vegan-donut-and-gelato-houston',
#    'name': 'Vegan Donut & Gelato',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SOo2-URHNR9eSbZu1EprGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vegan-donut-and-gelato-houston?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 156,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'gelato', 'title': 'Gelato'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.83603, 'longitude': -95.65301},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '16618 Clay Rd',
#     'address2': 'Ste 125',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77084',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['16618 Clay Rd', 'Ste 125', 'Houston, TX 77084']},
#    'phone': '+18325937788',
#    'display_phone': '(832) 593-7788',
#    'distance': 8042.493475586632},
#   {'id': 'MVwO9HUb1XyAB2s9YqZpgw',
#    'alias': 'yan-tea-katy-5',
#    'name': 'Yan Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kal8dHeuzPiWWrdJdLVCog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yan-tea-katy-5?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 111,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.793187772256527,
#     'longitude': -95.7742686116394},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '23119 Colonial Pkwy',
#     'address2': 'Ste B-5',
#     'address3': None,
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['23119 Colonial Pkwy', 'Ste B-5', 'Katy, TX 77449']},
#    'phone': '+18324370088',
#    'display_phone': '(832) 437-0088',
#    'distance': 5687.2130808996535},
#   {'id': 'EQWHV8Xoq8qDsD-ChL9mkw',
#    'alias': 'falafel-king-and-sweets-katy-flea-market-katy-2',
#    'name': 'Falafel King & Sweets/ Katy Flea Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ISTQL9L74e8IqrDuf9LQ_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/falafel-king-and-sweets-katy-flea-market-katy-2?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 40,
#    'categories': [{'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.82689, 'longitude': -95.72065},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3755 N Fry Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77449',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3755 N Fry Rd', 'Katy, TX 77449']},
#    'phone': '+17132617157',
#    'display_phone': '(713) 261-7157',
#    'distance': 1632.2595616264468},
#   {'id': 'zYmbcjQO4rpEDck_oWsNvQ',
#    'alias': 'kung-fu-tea-katy',
#    'name': 'Kung Fu Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jgAf-7vCoDDJo7yjIRkyRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kung-fu-tea-katy?adjust_creative=Edgd260bOX8AMj1-_K3q3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Edgd260bOX8AMj1-_K3q3w',
#    'review_count': 164,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7779900183246,
#     'longitude': -95.751204180944},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '501 S Mason Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Katy',
#     'zip_code': '77450',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['501 S Mason Rd', 'Katy, TX 77450']},
#    'phone': '+12812067339',
#    'display_phone': '(281) 206-7339',
#    'distance': 6205.495380867582}],
#  'total': 1600,
#  'region': {'center': {'longitude': -95.73623657226562,
#    'latitude': 29.83226513126808}}}
